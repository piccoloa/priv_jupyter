# %%
import twitter
import os
import pprint

# Go to http://dev.twitter.com/apps/new to create an app and get values
# for these credentials, which you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://developer.twitter.com/en/docs/basics/authentication/overview/oauth
# for more information on Twitter's OAuth implementation.

CONSUMER_KEY = os.environ['CONSUMER_KEY']
CONSUMER_SECRET = os.environ['CONSUMER_SECRET']
OAUTH_TOKEN = os.environ['ACCESS_TOKEN']
OAUTH_TOKEN_SECRET = os.environ['ACCESS_SECRET']

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# %%
# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x7f94d9f0fb70>

# %%
pp = pprint.PrettyPrinter(indent=2)

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

pp.pprint(world_trends)
# Out:
# [ { 'as_of': '2019-02-23T05:50:09Z',
#     'created_at': '2019-02-23T05:44:17Z',
#     'locations': [{'name': 'Worldwide', 'woeid': 1}],
#     'trends': [ { 'name': 'Paul George',
#                   'promoted_content': None,
#                   'query': '%22Paul+George%22',
#                   'tweet_volume': 33657,
#                   'url': 'http://twitter.com/search?q=%22Paul+George%22'},
#                 { 'name': '#MsQA2019TheFinaLChukchak',
#                   'promoted_content': None,
#                   'query': '%23MsQA2019TheFinaLChukchak',
#                   'tweet_volume': 47404,
#                   'url': 'http://twitter.com/search?q=%23MsQA2019TheFinaLChukchak'},
#                 { 'name': '#GalaViña19',
#                   'promoted_content': None,
#                   'query': '%23GalaVi%C3%B1a19',
#                   'tweet_volume': 111491,
#                   'url': 'http://twitter.com/search?q=%23GalaVi%C3%B1a19'},
#                 { 'name': '#ThunderUp',
#                   'promoted_content': None,
#                   'query': '%23ThunderUp',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23ThunderUp'},
#                 { 'name': '#BreakThrough',
#                   'promoted_content': None,
#                   'query': '%23BreakThrough',
#                   'tweet_volume': 11645,
#                   'url': 'http://twitter.com/search?q=%23BreakThrough'},
#                 { 'name': 'PETA',
#                   'promoted_content': None,
#                   'query': 'PETA',
#                   'tweet_volume': 161499,
#                   'url': 'http://twitter.com/search?q=PETA'},
#                 { 'name': '#PartyChilensisFtGala',
#                   'promoted_content': None,
#                   'query': '%23PartyChilensisFtGala',
#                   'tweet_volume': 146505,
#                   'url': 'http://twitter.com/search?q=%23PartyChilensisFtGala'},
#                 { 'name': 'ナナライ',
#                   'promoted_content': None,
#                   'query': '%E3%83%8A%E3%83%8A%E3%83%A9%E3%82%A4',
#                   'tweet_volume': 16852,
#                   'url': 'http://twitter.com/search?q=%E3%83%8A%E3%83%8A%E3%83%A9%E3%82%A4'},
#                 { 'name': 'Feinstein',
#                   'promoted_content': None,
#                   'query': 'Feinstein',
#                   'tweet_volume': 111530,
#                   'url': 'http://twitter.com/search?q=Feinstein'},
#                 { 'name': 'Brenda Mage',
#                   'promoted_content': None,
#                   'query': '%22Brenda+Mage%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22Brenda+Mage%22'},
#                 { 'name': 'Chad',
#                   'promoted_content': None,
#                   'query': 'Chad',
#                   'tweet_volume': 27024,
#                   'url': 'http://twitter.com/search?q=Chad'},
#                 { 'name': 'Double OT',
#                   'promoted_content': None,
#                   'query': '%22Double+OT%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22Double+OT%22'},
#                 { 'name': 'Donovan Mitchell',
#                   'promoted_content': None,
#                   'query': '%22Donovan+Mitchell%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22Donovan+Mitchell%22'},
#                 { 'name': 'Jordan Bohannon',
#                   'promoted_content': None,
#                   'query': '%22Jordan+Bohannon%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22Jordan+Bohannon%22'},
#                 { 'name': 'アプリ先行',
#                   'promoted_content': None,
#                   'query': '%E3%82%A2%E3%83%97%E3%83%AA%E5%85%88%E8%A1%8C',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%E3%82%A2%E3%83%97%E3%83%AA%E5%85%88%E8%A1%8C'},
#                 { 'name': 'Tonka',
#                   'promoted_content': None,
#                   'query': 'Tonka',
#                   'tweet_volume': 11533,
#                   'url': 'http://twitter.com/search?q=Tonka'},
#                 { 'name': 'POR FIN ARISTEMO',
#                   'promoted_content': None,
#                   'query': '%22POR+FIN+ARISTEMO%22',
#                   'tweet_volume': 113901,
#                   'url': 'http://twitter.com/search?q=%22POR+FIN+ARISTEMO%22'},
#                 { 'name': 'Di Mondo',
#                   'promoted_content': None,
#                   'query': '%22Di+Mondo%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22Di+Mondo%22'},
#                 { 'name': 'Gobert',
#                   'promoted_content': None,
#                   'query': 'Gobert',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=Gobert'},
#                 { 'name': 'Diego Boneta',
#                   'promoted_content': None,
#                   'query': '%22Diego+Boneta%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22Diego+Boneta%22'},
#                 { 'name': 'Shanghai Dragons',
#                   'promoted_content': None,
#                   'query': '%22Shanghai+Dragons%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22Shanghai+Dragons%22'},
#                 { 'name': 'HOY BESO ARISTEMO',
#                   'promoted_content': None,
#                   'query': '%22HOY+BESO+ARISTEMO%22',
#                   'tweet_volume': 234513,
#                   'url': 'http://twitter.com/search?q=%22HOY+BESO+ARISTEMO%22'},
#                 { 'name': 'お気に入りの武器',
#                   'promoted_content': None,
#                   'query': '%E3%81%8A%E6%B0%97%E3%81%AB%E5%85%A5%E3%82%8A%E3%81%AE%E6%AD%A6%E5%99%A8',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%E3%81%8A%E6%B0%97%E3%81%AB%E5%85%A5%E3%82%8A%E3%81%AE%E6%AD%A6%E5%99%A8'},
#                 { 'name': 'オープン戦',
#                   'promoted_content': None,
#                   'query': '%E3%82%AA%E3%83%BC%E3%83%97%E3%83%B3%E6%88%A6',
#                   'tweet_volume': 23304,
#                   'url': 'http://twitter.com/search?q=%E3%82%AA%E3%83%BC%E3%83%97%E3%83%B3%E6%88%A6'},
#                 { 'name': 'Vesta',
#                   'promoted_content': None,
#                   'query': 'Vesta',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=Vesta'},
#                 { 'name': 'Brody Stevens',
#                   'promoted_content': None,
#                   'query': '%22Brody+Stevens%22',
#                   'tweet_volume': 28605,
#                   'url': 'http://twitter.com/search?q=%22Brody+Stevens%22'},
#                 { 'name': 'JamesReid OnItsShowtime',
#                   'promoted_content': None,
#                   'query': '%22JamesReid+OnItsShowtime%22',
#                   'tweet_volume': 38032,
#                   'url': 'http://twitter.com/search?q=%22JamesReid+OnItsShowtime%22'},
#                 { 'name': 'Joe Ingles',
#                   'promoted_content': None,
#                   'query': '%22Joe+Ingles%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22Joe+Ingles%22'},
#                 { 'name': '#GATPAT',
#                   'promoted_content': None,
#                   'query': '%23GATPAT',
#                   'tweet_volume': 139023,
#                   'url': 'http://twitter.com/search?q=%23GATPAT'},
#                 { 'name': '#あなたの武器適性',
#                   'promoted_content': None,
#                   'query': '%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AE%E6%AD%A6%E5%99%A8%E9%81%A9%E6%80%A7',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AE%E6%AD%A6%E5%99%A8%E9%81%A9%E6%80%A7'},
#                 { 'name': '#ツイートを解析してあなたを猫にしてみた',
#                   'promoted_content': None,
#                   'query': '%23%E3%83%84%E3%82%A4%E3%83%BC%E3%83%88%E3%82%92%E8%A7%A3%E6%9E%90%E3%81%97%E3%81%A6%E3%81%82%E3%81%AA%E3%81%9F%E3%82%92%E7%8C%AB%E3%81%AB%E3%81%97%E3%81%A6%E3%81%BF%E3%81%9F',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23%E3%83%84%E3%82%A4%E3%83%BC%E3%83%88%E3%82%92%E8%A7%A3%E6%9E%90%E3%81%97%E3%81%A6%E3%81%82%E3%81%AA%E3%81%9F%E3%82%92%E7%8C%AB%E3%81%AB%E3%81%97%E3%81%A6%E3%81%BF%E3%81%9F'},
#                 { 'name': '#AdamKutnerPowerPlay',
#                   'promoted_content': None,
#                   'query': '%23AdamKutnerPowerPlay',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23AdamKutnerPowerPlay'},
#                 { 'name': '#TatakADN',
#                   'promoted_content': None,
#                   'query': '%23TatakADN',
#                   'tweet_volume': 133433,
#                   'url': 'http://twitter.com/search?q=%23TatakADN'},
#                 { 'name': '#UTAvsOKC',
#                   'promoted_content': None,
#                   'query': '%23UTAvsOKC',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23UTAvsOKC'},
#                 { 'name': '#1001AlasanPutus',
#                   'promoted_content': None,
#                   'query': '%231001AlasanPutus',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%231001AlasanPutus'},
#                 { 'name': '#MVPG',
#                   'promoted_content': None,
#                   'query': '%23MVPG',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23MVPG'},
#                 { 'name': '#UlanMediaConference',
#                   'promoted_content': None,
#                   'query': '%23UlanMediaConference',
#                   'tweet_volume': 48566,
#                   'url': 'http://twitter.com/search?q=%23UlanMediaConference'},
#                 { 'name': '#Cumartesi',
#                   'promoted_content': None,
#                   'query': '%23Cumartesi',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23Cumartesi'},
#                 { 'name': '#UTAatOKC',
#                   'promoted_content': None,
#                   'query': '%23UTAatOKC',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23UTAatOKC'},
#                 { 'name': '#SearchForGrog',
#                   'promoted_content': None,
#                   'query': '%23SearchForGrog',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23SearchForGrog'},
#                 { 'name': '#ALDUBxADNLoveRemains',
#                   'promoted_content': None,
#                   'query': '%23ALDUBxADNLoveRemains',
#                   'tweet_volume': 89463,
#                   'url': 'http://twitter.com/search?q=%23ALDUBxADNLoveRemains'},
#                 { 'name': '#dek62',
#                   'promoted_content': None,
#                   'query': '%23dek62',
#                   'tweet_volume': 161611,
#                   'url': 'http://twitter.com/search?q=%23dek62'},
#                 { 'name': '#LoveAfterLockup',
#                   'promoted_content': None,
#                   'query': '%23LoveAfterLockup',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23LoveAfterLockup'},
#                 { 'name': '#GalaVina2019',
#                   'promoted_content': None,
#                   'query': '%23GalaVina2019',
#                   'tweet_volume': 15367,
#                   'url': 'http://twitter.com/search?q=%23GalaVina2019'},
#                 { 'name': '#あなたが好きな人に言われたい台詞',
#                   'promoted_content': None,
#                   'query': '%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%8C%E5%A5%BD%E3%81%8D%E3%81%AA%E4%BA%BA%E3%81%AB%E8%A8%80%E3%82%8F%E3%82%8C%E3%81%9F%E3%81%84%E5%8F%B0%E8%A9%9E',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%8C%E5%A5%BD%E3%81%8D%E3%81%AA%E4%BA%BA%E3%81%AB%E8%A8%80%E3%82%8F%E3%82%8C%E3%81%9F%E3%81%84%E5%8F%B0%E8%A9%9E'},
#                 { 'name': '#PG13',
#                   'promoted_content': None,
#                   'query': '%23PG13',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23PG13'},
#                 { 'name': '#SaturdayMotivation',
#                   'promoted_content': None,
#                   'query': '%23SaturdayMotivation',
#                   'tweet_volume': 11215,
#                   'url': 'http://twitter.com/search?q=%23SaturdayMotivation'},
#                 { 'name': '#TeamIsEverything',
#                   'promoted_content': None,
#                   'query': '%23TeamIsEverything',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23TeamIsEverything'},
#                 { 'name': '#富士山の日',
#                   'promoted_content': None,
#                   'query': '%23%E5%AF%8C%E5%A3%AB%E5%B1%B1%E3%81%AE%E6%97%A5',
#                   'tweet_volume': 20929,
#                   'url': 'http://twitter.com/search?q=%23%E5%AF%8C%E5%A3%AB%E5%B1%B1%E3%81%AE%E6%97%A5'},
#                 { 'name': '#道フェス',
#                   'promoted_content': None,
#                   'query': '%23%E9%81%93%E3%83%95%E3%82%A7%E3%82%B9',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23%E9%81%93%E3%83%95%E3%82%A7%E3%82%B9'}]}]

# %%
pp.pprint(us_trends)
# Out:
# [ { 'as_of': '2019-02-23T05:50:09Z',
#     'created_at': '2019-02-23T05:44:17Z',
#     'locations': [{'name': 'United States', 'woeid': 23424977}],
#     'trends': [ { 'name': 'Paul George',
#                   'promoted_content': None,
#                   'query': '%22Paul+George%22',
#                   'tweet_volume': 33657,
#                   'url': 'http://twitter.com/search?q=%22Paul+George%22'},
#                 { 'name': '#ThunderUp',
#                   'promoted_content': None,
#                   'query': '%23ThunderUp',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23ThunderUp'},
#                 { 'name': 'PETA',
#                   'promoted_content': None,
#                   'query': 'PETA',
#                   'tweet_volume': 161499,
#                   'url': 'http://twitter.com/search?q=PETA'},
#                 { 'name': '#BreakThrough',
#                   'promoted_content': None,
#                   'query': '%23BreakThrough',
#                   'tweet_volume': 11645,
#                   'url': 'http://twitter.com/search?q=%23BreakThrough'},
#                 { 'name': 'Feinstein',
#                   'promoted_content': None,
#                   'query': 'Feinstein',
#                   'tweet_volume': 111530,
#                   'url': 'http://twitter.com/search?q=Feinstein'},
#                 { 'name': 'Donovan Mitchell',
#                   'promoted_content': None,
#                   'query': '%22Donovan+Mitchell%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22Donovan+Mitchell%22'},
#                 { 'name': 'Double OT',
#                   'promoted_content': None,
#                   'query': '%22Double+OT%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22Double+OT%22'},
#                 { 'name': 'Jordan Bohannon',
#                   'promoted_content': None,
#                   'query': '%22Jordan+Bohannon%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22Jordan+Bohannon%22'},
#                 { 'name': '#UTAvsOKC',
#                   'promoted_content': None,
#                   'query': '%23UTAvsOKC',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23UTAvsOKC'},
#                 { 'name': 'Gobert',
#                   'promoted_content': None,
#                   'query': 'Gobert',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=Gobert'},
#                 { 'name': '#UTAatOKC',
#                   'promoted_content': None,
#                   'query': '%23UTAatOKC',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23UTAatOKC'},
#                 { 'name': '#SearchForGrog',
#                   'promoted_content': None,
#                   'query': '%23SearchForGrog',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23SearchForGrog'},
#                 { 'name': 'Joe Ingles',
#                   'promoted_content': None,
#                   'query': '%22Joe+Ingles%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22Joe+Ingles%22'},
#                 { 'name': 'Brody Stevens',
#                   'promoted_content': None,
#                   'query': '%22Brody+Stevens%22',
#                   'tweet_volume': 28605,
#                   'url': 'http://twitter.com/search?q=%22Brody+Stevens%22'},
#                 { 'name': 'Rubio',
#                   'promoted_content': None,
#                   'query': 'Rubio',
#                   'tweet_volume': 68968,
#                   'url': 'http://twitter.com/search?q=Rubio'},
#                 { 'name': 'PG for MVP',
#                   'promoted_content': None,
#                   'query': '%22PG+for+MVP%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22PG+for+MVP%22'},
#                 { 'name': 'DiFi',
#                   'promoted_content': None,
#                   'query': 'DiFi',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=DiFi'},
#                 { 'name': 'Steven Adams',
#                   'promoted_content': None,
#                   'query': '%22Steven+Adams%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22Steven+Adams%22'},
#                 { 'name': 'Abdel Nader',
#                   'promoted_content': None,
#                   'query': '%22Abdel+Nader%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22Abdel+Nader%22'},
#                 { 'name': 'THEY DID IT',
#                   'promoted_content': None,
#                   'query': '%22THEY+DID+IT%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22THEY+DID+IT%22'},
#                 { 'name': 'The Jazz',
#                   'promoted_content': None,
#                   'query': '%22The+Jazz%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22The+Jazz%22'},
#                 { 'name': 'Korver',
#                   'promoted_content': None,
#                   'query': 'Korver',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=Korver'},
#                 { 'name': 'Playoff P',
#                   'promoted_content': None,
#                   'query': '%22Playoff+P%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22Playoff+P%22'},
#                 { 'name': 'Russ and PG',
#                   'promoted_content': None,
#                   'query': '%22Russ+and+PG%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22Russ+and+PG%22'},
#                 { 'name': 'PG MVP',
#                   'promoted_content': None,
#                   'query': '%22PG+MVP%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22PG+MVP%22'},
#                 { 'name': 'I WAS HERE',
#                   'promoted_content': None,
#                   'query': '%22I+WAS+HERE%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22I+WAS+HERE%22'},
#                 { 'name': 'PAUL MF GEORGE',
#                   'promoted_content': None,
#                   'query': '%22PAUL+MF+GEORGE%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22PAUL+MF+GEORGE%22'},
#                 { 'name': 'Jae Crowder',
#                   'promoted_content': None,
#                   'query': '%22Jae+Crowder%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22Jae+Crowder%22'},
#                 { 'name': 'Ms. Lucas',
#                   'promoted_content': None,
#                   'query': '%22Ms.+Lucas%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22Ms.+Lucas%22'},
#                 { 'name': 'DeMar',
#                   'promoted_content': None,
#                   'query': 'DeMar',
#                   'tweet_volume': 48646,
#                   'url': 'http://twitter.com/search?q=DeMar'},
#                 { 'name': 'Jerami Grant',
#                   'promoted_content': None,
#                   'query': '%22Jerami+Grant%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22Jerami+Grant%22'},
#                 { 'name': 'PG and Russ',
#                   'promoted_content': None,
#                   'query': '%22PG+and+Russ%22',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%22PG+and+Russ%22'},
#                 { 'name': '#LoveAfterLockup',
#                   'promoted_content': None,
#                   'query': '%23LoveAfterLockup',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23LoveAfterLockup'},
#                 { 'name': '#MVPG',
#                   'promoted_content': None,
#                   'query': '%23MVPG',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23MVPG'},
#                 { 'name': '#AdamKutnerPowerPlay',
#                   'promoted_content': None,
#                   'query': '%23AdamKutnerPowerPlay',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23AdamKutnerPowerPlay'},
#                 { 'name': '#PG13',
#                   'promoted_content': None,
#                   'query': '%23PG13',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23PG13'},
#                 { 'name': '#ShanghaiDragons',
#                   'promoted_content': None,
#                   'query': '%23ShanghaiDragons',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23ShanghaiDragons'},
#                 { 'name': '#TeamIsEverything',
#                   'promoted_content': None,
#                   'query': '%23TeamIsEverything',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23TeamIsEverything'},
#                 { 'name': '#RomComNomNom',
#                   'promoted_content': None,
#                   'query': '%23RomComNomNom',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23RomComNomNom'},
#                 { 'name': '#ShepHappens',
#                   'promoted_content': None,
#                   'query': '%23ShepHappens',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23ShepHappens'},
#                 { 'name': '#RIPBrodyStevens',
#                   'promoted_content': None,
#                   'query': '%23RIPBrodyStevens',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23RIPBrodyStevens'},
#                 { 'name': '#OKCvsUTAH',
#                   'promoted_content': None,
#                   'query': '%23OKCvsUTAH',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23OKCvsUTAH'},
#                 { 'name': '#NationalMargartiaDay',
#                   'promoted_content': None,
#                   'query': '%23NationalMargartiaDay',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23NationalMargartiaDay'},
#                 { 'name': '#ButIWontBeIgnored',
#                   'promoted_content': None,
#                   'query': '%23ButIWontBeIgnored',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23ButIWontBeIgnored'},
#                 { 'name': '#TheBlacklist',
#                   'promoted_content': None,
#                   'query': '%23TheBlacklist',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23TheBlacklist'},
#                 { 'name': '#AnteUp',
#                   'promoted_content': None,
#                   'query': '%23AnteUp',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23AnteUp'},
#                 { 'name': '#PicturePerfect',
#                   'promoted_content': None,
#                   'query': '%23PicturePerfect',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23PicturePerfect'},
#                 { 'name': '#NationalMargaritaDay2019',
#                   'promoted_content': None,
#                   'query': '%23NationalMargaritaDay2019',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23NationalMargaritaDay2019'},
#                 { 'name': '#UFC236',
#                   'promoted_content': None,
#                   'query': '%23UFC236',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23UFC236'},
#                 { 'name': '#Dateline',
#                   'promoted_content': None,
#                   'query': '%23Dateline',
#                   'tweet_volume': None,
#                   'url': 'http://twitter.com/search?q=%23Dateline'}]}]
